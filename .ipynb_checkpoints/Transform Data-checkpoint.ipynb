# %%
# Add dependencies
import glob
import pandas as pd

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
clean_data_ridership = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True)
# Out:
# C:\Users\CodyS\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
clean_data_ridership.head()
# Out:
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             4209
# 1                                             2702
# 2                                             2358
# 3                                             5662
# 4                                             3344
#
#    3-Day Passes Purchased (midnight to 11:59 pm) Column 1    Date  \
# 0                                            211      NaN  7/1/18
# 1                                            241      NaN  7/2/18
# 2                                            199      NaN  7/3/18
# 3                                            250      NaN  7/4/18
# 4                                            264      NaN  7/5/18
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120484
# 1                                       130122
# 2                                       113998
# 3                                       136287
# ...

# %%
clean_data_ridership.count()
# Out:
# 24-Hour Passes Purchased (midnight to 11:59 pm)       345
# 3-Day Passes Purchased (midnight to 11:59 pm)         345
# Column 1                                               71
# Date                                                  345
# Miles traveled today (midnight to 11:59 pm)           345
# Total Annual Members (All Time)                       345
# Trips over the past 24-hours (midnight to 11:59pm)    345
# dtype: int64

# %%
clean_data_trip.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
clean_data_trip.count()
# Out:
# tripduration               729927
# starttime                  729927
# stoptime                   729927
# start station id           729927
# start station name         729927
# start station latitude     729927
# start station longitude    729927
# end station id             729927
# end station name           729927
# end station latitude       729927
# end station longitude      729927
# bikeid                     729927
# usertype                   729927
# birth year                 729927
# gender                     729927
# dtype: int64

# %%
# Export to csv
clean_data_ridership.to_csv("clean_data/clean_quarter_data.csv")
clean_data_trip.to_csv("clean_data/clean_data.csv")
